# %% [markdown]
# <a href="https://colab.research.google.com/github/MIHIR-110103/Cropify/blob/main/Final_ML_Mini_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # E.D.A.

# %% [markdown]
# ## Data Loading & Pre-Processing

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/apy (1).csv")
df
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production
# 0                  Arecanut    1254.0      2000.0
# ...

# %%
df.shape
# Out:
# (246091, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246091 entries, 0 to 246090
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   State_Name     246091 non-null  object
#  1   District_Name  246091 non-null  object
#  2   Crop_Year      246091 non-null  int64
#  3   Season         246091 non-null  object
#  4   Crop           246091 non-null  object
#  5   Area           246091 non-null  float64
#  6   Production     242361 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.1+ MB

# %%
df.isnull().sum()
# Out:
# State_Name          0
# District_Name       0
# Crop_Year           0
# Season              0
# Crop                0
# Area                0
# Production       3730
# dtype: int64

# %%
mean_prod=(3730/242361)*100
mean_prod
# Out:
# 1.5390264935365014

# %%
df1=pd.DataFrame(df)

# %%
df1.dropna(subset=["Production"],axis=0,inplace=True)

# %%
df1.isnull().sum()
# Out:
# State_Name       0
# District_Name    0
# Crop_Year        0
# Season           0
# Crop             0
# Area             0
# Production       0
# dtype: int64

# %%
plt.tick_params(labelsize=10)
sns.heatmap(df1.corr(),annot=True);
# Out:
# <ipython-input-11-a8a0f8610a10>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df1.corr(),annot=True);

# %% [markdown]
# No variable shows high corelation with other variables.

# %% [markdown]
# ## STATE WISE ANALYSIS:

# %%
df1.State_Name.nunique()
# Out:
# 33

# %% [markdown]
# 33 Unique states data available

# %%
df1.State_Name.unique()
# Out:
# array(['Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadra and Nagar Haveli', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal Pradesh', 'Jammu and Kashmir ', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
#        'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Puducherry',
#        'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana ',
#        'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'West Bengal'],
#       dtype=object)

# %%
df.State_Name.value_counts()
# Out:
# Uttar Pradesh                  33306
# Madhya Pradesh                 22943
# Karnataka                      21122
# Bihar                          18885
# Assam                          14628
# Odisha                         13575
# Tamil Nadu                     13547
# Maharashtra                    12628
# Rajasthan                      12514
# Chhattisgarh                   10709
# Andhra Pradesh                  9628
# West Bengal                     9613
# Gujarat                         8436
# Haryana                         5875
# Telangana                       5649
# Uttarakhand                     4896
# Kerala                          4261
# Nagaland                        3906
# Punjab                          3173
# Meghalaya                       2867
# Arunachal Pradesh               2546
# Himachal Pradesh                2494
# Jammu and Kashmir               1634
# Tripura                         1412
# Manipur                         1267
# ...

# %% [markdown]
# ## DISTRICT WISE ANALYSIS:

# %%
df1.District_Name.nunique()
# Out:
# 646

# %%
df1.District_Name.unique()
# Out:
# array(['NICOBARS', 'NORTH AND MIDDLE ANDAMAN', 'SOUTH ANDAMANS',
#        'ANANTAPUR', 'CHITTOOR', 'EAST GODAVARI', 'GUNTUR', 'KADAPA',
#        'KRISHNA', 'KURNOOL', 'PRAKASAM', 'SPSR NELLORE', 'SRIKAKULAM',
#        'VISAKHAPATANAM', 'VIZIANAGARAM', 'WEST GODAVARI', 'ANJAW',
#        'CHANGLANG', 'DIBANG VALLEY', 'EAST KAMENG', 'EAST SIANG',
#        'KURUNG KUMEY', 'LOHIT', 'LONGDING', 'LOWER DIBANG VALLEY',
#        'LOWER SUBANSIRI', 'NAMSAI', 'PAPUM PARE', 'TAWANG', 'TIRAP',
#        'UPPER SIANG', 'UPPER SUBANSIRI', 'WEST KAMENG', 'WEST SIANG',
#        'BAKSA', 'BARPETA', 'BONGAIGAON', 'CACHAR', 'CHIRANG', 'DARRANG',
#        'DHEMAJI', 'DHUBRI', 'DIBRUGARH', 'DIMA HASAO', 'GOALPARA',
#        'GOLAGHAT', 'HAILAKANDI', 'JORHAT', 'KAMRUP', 'KAMRUP METRO',
#        'KARBI ANGLONG', 'KARIMGANJ', 'KOKRAJHAR', 'LAKHIMPUR', 'MARIGAON',
#        'NAGAON', 'NALBARI', 'SIVASAGAR', 'SONITPUR', 'TINSUKIA',
#        'UDALGURI', 'ARARIA', 'ARWAL', 'AURANGABAD', 'BANKA', 'BEGUSARAI',
# ...

# %%
df1.District_Name.value_counts()
# Out:
# TUMKUR       931
# BELGAUM      924
# BIJAPUR      905
# HASSAN       895
# BELLARY      887
#             ...
# HYDERABAD      8
# KHUNTI         6
# RAMGARH        6
# NAMSAI         1
# MUMBAI         1
# Name: District_Name, Length: 646, dtype: int64

# %% [markdown]
# ### CROP YEAR WISE ANALYSIS:

# %%
print(df1.Crop_Year.min())
print(df1.Crop_Year.max())
print(df1.Crop_Year.nunique())
# Out:
# 1997
# 2015
# 19

# %%
df1.Crop_Year.value_counts()
# Out:
# 2003    17139
# 2002    16536
# 2007    14269
# 2008    14230
# 2006    13976
# 2004    13858
# 2010    13793
# 2011    13791
# 2009    13767
# 2000    13553
# 2005    13519
# 2013    13475
# 2001    13293
# 2012    13184
# 1999    12441
# 1998    11262
# 2014    10815
# 1997     8899
# 2015      561
# Name: Crop_Year, dtype: int64

# %% [markdown]
# ## SEASON WISE ANALYSIS:

# %%
df1.Season.nunique()
# Out:
# 6

# %%
df1.Season.unique()
# Out:
# array(['Kharif     ', 'Whole Year ', 'Autumn     ', 'Rabi       ',
#        'Summer     ', 'Winter     '], dtype=object)

# %%
df1.Season.value_counts()
# Out:
# Kharif         94283
# Rabi           66160
# Whole Year     56127
# Summer         14811
# Winter          6050
# Autumn          4930
# Name: Season, dtype: int64

# %% [markdown]
# ## CROP WISE ANALYSIS:

# %%
df1.Crop.nunique()
# Out:
# 124

# %%
df1.Crop.unique()
# Out:
# array(['Arecanut', 'Other Kharif pulses', 'Rice', 'Banana', 'Cashewnut',
#        'Coconut ', 'Dry ginger', 'Sugarcane', 'Sweet potato', 'Tapioca',
#        'Black pepper', 'Dry chillies', 'other oilseeds', 'Turmeric',
#        'Maize', 'Moong(Green Gram)', 'Urad', 'Arhar/Tur', 'Groundnut',
#        'Sunflower', 'Bajra', 'Castor seed', 'Cotton(lint)', 'Horse-gram',
#        'Jowar', 'Korra', 'Ragi', 'Tobacco', 'Gram', 'Wheat', 'Masoor',
#        'Sesamum', 'Linseed', 'Safflower', 'Onion', 'other misc. pulses',
#        'Samai', 'Small millets', 'Coriander', 'Potato',
#        'Other  Rabi pulses', 'Soyabean', 'Beans & Mutter(Vegetable)',
#        'Bhindi', 'Brinjal', 'Citrus Fruit', 'Cucumber', 'Grapes', 'Mango',
#        'Orange', 'other fibres', 'Other Fresh Fruits', 'Other Vegetables',
#        'Papaya', 'Pome Fruit', 'Tomato', 'Mesta', 'Cowpea(Lobia)',
#        'Lemon', 'Pome Granet', 'Sapota', 'Cabbage', 'Rapeseed &Mustard',
# ...

# %%
df1.Crop.value_counts()
# Out:
# Rice                 15082
# Maize                13787
# Moong(Green Gram)    10106
# Urad                  9710
# Sesamum               8821
#                      ...
# Litchi                   6
# Coffee                   6
# Apple                    4
# Peach                    4
# Other Dry Fruit          1
# Name: Crop, Length: 124, dtype: int64

# %% [markdown]
# ## ZONE SEGREGATION:

# %%
north_india = ['Jammu and Kashmir', 'Punjab', 'Himachal Pradesh', 'Haryana', 'Uttarakhand', 'Uttar Pradesh', 'Chandigarh']
east_india = ['Bihar', 'Odisha', 'Jharkhand', 'West Bengal']
south_india = ['Andhra Pradesh', 'Karnataka', 'Kerala' ,'Tamil Nadu', 'Telangana']
west_india = ['Rajasthan' , 'Gujarat', 'Goa','Maharashtra']
central_india = ['Madhya Pradesh', 'Chhattisgarh']
north_east_india = ['Assam', 'Sikkim', 'Nagaland', 'Meghalaya', 'Manipur', 'Mizoram', 'Tripura', 'Arunachal Pradesh']
ut_india = ['Andaman and Nicobar Islands', 'Dadra and Nagar Haveli', 'Puducherry']

# %%
def get_zonal_names(row):
    if row['State_Name'].strip() in north_india:
        val = 'North Zone'
    elif row['State_Name'].strip()  in south_india:
        val = 'South Zone'
    elif row['State_Name'].strip()  in east_india:
        val = 'East Zone'
    elif row['State_Name'].strip()  in west_india:
        val = 'West Zone'
    elif row['State_Name'].strip()  in central_india:
        val = 'Central Zone'
    elif row['State_Name'].strip()  in north_east_india:
        val = 'NE Zone'
    elif row['State_Name'].strip()  in ut_india:
        val = 'Union Terr'
    else:
        val = 'No Value'
    return val

df1['Zones']=df1.apply(get_zonal_names, axis=1)
df1['Zones'].unique()
# Out:
# array(['Union Terr', 'South Zone', 'NE Zone', 'East Zone', 'North Zone',
#        'Central Zone', 'West Zone'], dtype=object)

# %%
df1
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production       Zones
# ...

# %%
df1.Zones.value_counts()
# Out:
# South Zone      53500
# North Zone      49874
# East Zone       43261
# West Zone       33134
# Central Zone    32972
# NE Zone         28284
# Union Terr       1336
# Name: Zones, dtype: int64

# %% [markdown]
# ## CROP CATEGORY SEGREGATION:

# %%
crop=df1['Crop']
def cat_crop(crop):
    for i in ['Rice','Maize','Wheat','Barley','Varagu','Other Cereals & Millets','Ragi','Small millets','Bajra','Jowar', 'Paddy','Total foodgrain','Jobster']:
        if crop==i:
            return 'Cereal'
    for i in ['Moong','Urad','Arhar/Tur','Peas & beans','Masoor',
              'Other Kharif pulses','other misc. pulses','Ricebean (nagadal)',
              'Rajmash Kholar','Lentil','Samai','Blackgram','Korra','Cowpea(Lobia)',
              'Other  Rabi pulses','Other Kharif pulses','Peas & beans (Pulses)','Pulses total','Gram']:
        if crop==i:
            return 'Pulses'
    for i in ['Peach','Apple','Litchi','Pear','Plums','Ber','Sapota','Lemon','Pome Granet',
               'Other Citrus Fruit','Water Melon','Jack Fruit','Grapes','Pineapple','Orange',
               'Pome Fruit','Citrus Fruit','Other Fresh Fruits','Mango','Papaya','Coconut','Banana']:
        if crop==i:
            return 'Fruits'
    for i in ['Bean','Lab-Lab','Moth','Guar seed','Soyabean','Horse-gram']:
        if crop==i:
            return 'Beans'
    for i in ['Turnip','Peas','Beet Root','Carrot','Yam','Ribed Guard','Ash Gourd ','Pump Kin','Redish','Snak Guard','Bottle Gourd',
              'Bitter Gourd','Cucumber','Drum Stick','Cauliflower','Beans & Mutter(Vegetable)','Cabbage',
              'Bhindi','Tomato','Brinjal','Khesari','Sweet potato','Potato','Onion','Tapioca','Colocosia']:
              if crop==i:
                return 'Vegetables'
    for i in ['Perilla','Ginger','Cardamom','Black pepper','Dry ginger','Garlic','Coriander','Turmeric','Dry chillies','Cond-spcs other']:
        if crop==i:
            return 'spices'
    for i in ['other fibres','Kapas','Jute & mesta','Jute','Mesta','Cotton(lint)','Sannhamp']:
        if crop==i:
            return 'fibres'
    for i in ['Arcanut (Processed)','Atcanut (Raw)','Cashewnut Processed','Cashewnut Raw','Cashewnut','Arecanut','Groundnut']:
        if crop==i:
            return 'Nuts'
    for i in ['other oilseeds','Safflower','Niger seed','Castor seed','Linseed','Sunflower','Rapeseed &Mustard','Sesamum','Oilseeds total']:
        if crop==i:
            return 'oilseeds'
    for i in ['Tobacco','Coffee','Tea','Sugarcane','Rubber']:
        if crop==i:
            return 'Commercial'

df1['cat_crop']=df1['Crop'].apply(cat_crop)

# %%
df1
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production       Zones    cat_crop
# ...

# %%
df1["cat_crop"].value_counts()
# Out:
# Cereal        63283
# Pulses        40898
# oilseeds      33801
# Vegetables    23154
# spices        21638
# Nuts          11472
# Commercial    10561
# fibres         9785
# Beans          9115
# Fruits         6153
# Name: cat_crop, dtype: int64

# %%
labels_to_remove = ['oilseeds','spices','Nuts','Commercial','fibres','Beans','Fruits']

# filter out rows containing the specified labels
DF = df1[~df1['cat_crop'].isin(labels_to_remove)]
DF1 = DF[DF['cat_crop'].notna()]
# display the resulting DataFrame
DF1.head()
# Out:
#                      State_Name District_Name  Crop_Year       Season  \
# 1   Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2   Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 8   Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 9   Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 11  Andaman and Nicobar Islands      NICOBARS       2001  Kharif
#
#                    Crop   Area  Production       Zones    cat_crop
# 1   Other Kharif pulses    2.0         1.0  Union Terr      Pulses
# 2                  Rice  102.0       321.0  Union Terr      Cereal
# 8          Sweet potato    5.0        15.0  Union Terr  Vegetables
# 9               Tapioca   40.0       169.0  Union Terr  Vegetables
# 11  Other Kharif pulses    2.0         1.0  Union Terr      Pulses

# %% [markdown]
# ## VISUALISATIONS:

# %%
df2=df1.copy()

# %%
df2
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production       Zones    cat_crop
# ...

# %%
plt.figure(figsize=(21,10))
sns.scatterplot(data=df2,x="State_Name",y="cat_crop",hue="Season",s=200)
plt.legend(loc='lower left')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# From the above scatter plot we can get an overlook of which category of crop is being harvested in each State.

# %%
a=df2.groupby(df2['Zones'])['Production'].sum()

# %%
df3=pd.DataFrame(a)

# %%
df3
# Out:
#                 Production
# Zones
# Central Zone  5.497926e+08
# East Zone     1.936070e+09
# NE Zone       2.165305e+09
# North Zone    4.365489e+09
# South Zone    1.284797e+11
# Union Terr    1.104796e+09
# West Zone     2.575008e+09

# %%
df3['Zones']=df3.index

# %%
df3=df3.sort_values(by='Production',ascending=False)

# %%
df3
# Out:
#                 Production         Zones
# Zones
# South Zone    1.284797e+11    South Zone
# North Zone    4.365489e+09    North Zone
# West Zone     2.575008e+09     West Zone
# NE Zone       2.165305e+09       NE Zone
# East Zone     1.936070e+09     East Zone
# Union Terr    1.104796e+09    Union Terr
# Central Zone  5.497926e+08  Central Zone

# %%
plt.figure(figsize=(10,10))
sns.barplot(x='Zones',y='Production',data=df3)
plt.yscale('log')
plt.title('Zone-Wise Production: Total')
# Out:
# Text(0.5, 1.0, 'Zone-Wise Production: Total')

# %% [markdown]
# From the above Visualisation we can interpret that most of the crop production in India comes from Southern India.

# %%
df4 =  df2[(df2["Zones"] == 'South Zone')]
plt.figure(figsize=(10,10))
sns.barplot(x='State_Name',y='Production',data=df4)
plt.yscale('log')
plt.title('Southern-Zone Production')
# Out:
# Text(0.5, 1.0, 'Southern-Zone Production')

# %%
b=df4.groupby('State_Name')['Area'].sum()

# %%
df5=pd.DataFrame(b)
df5['State_Name']=df5.index
df5
# Out:
#                         Area      State_Name
# State_Name
# Andhra Pradesh  1.315073e+08  Andhra Pradesh
# Karnataka       2.029086e+08       Karnataka
# Kerala          3.180225e+07          Kerala
# Tamil Nadu      9.541695e+07      Tamil Nadu
# Telangana       8.131065e+07      Telangana

# %%
plt.figure(figsize=(10,10))
plt.pie(df5['Area'], labels=df5['State_Name'],autopct='%.0f%%')
plt.title('Southern-Zone Area Distribution')
plt.show()

# %% [markdown]
# From above two graphs we can see that even though Kerala has less goegraphical area (around 6%) it still contributes majority of the crop production in Southern India whereas Karnataka having 37% geographical area has less crop production in Southern India.

# %%
df4['cat_crop'].nunique()
# Out:
# 10

# %%
df4['cat_crop'].unique()
# Out:
# array(['Pulses', 'Cereal', 'oilseeds', 'fibres', 'spices', 'Nuts',
#        'Beans', None, 'Commercial', 'Vegetables', 'Fruits'], dtype=object)

# %%
df6 =  df4[(df4["State_Name"] == 'Kerala')]
plt.figure(figsize=(10,10))
sns.barplot(x='cat_crop',y='Production',data=df6)
#plt.yscale('log')
plt.title('Category Wise Production In Kerala')
# Out:
# Text(0.5, 1.0, 'Category Wise Production In Kerala')

# %% [markdown]
#  In Kerala vegetables are mass produced than the other food categories.

# %%
df6
# Out:
#        State_Name District_Name  Crop_Year       Season          Crop  \
# 97987      Kerala     ALAPPUZHA       1997  Whole Year       Arecanut
# 97988      Kerala     ALAPPUZHA       1997  Whole Year   Black pepper
# 97989      Kerala     ALAPPUZHA       1997  Whole Year      Cashewnut
# 97990      Kerala     ALAPPUZHA       1997  Whole Year       Coconut
# 97991      Kerala     ALAPPUZHA       1997  Whole Year        Tapioca
# ...           ...           ...        ...          ...           ...
# 102242     Kerala       WAYANAD       2014  Whole Year        Sesamum
# 102244     Kerala       WAYANAD       2014  Whole Year   Sweet potato
# 102245     Kerala       WAYANAD       2014  Whole Year        Tapioca
# 102246     Kerala       WAYANAD       2014  Whole Year       Turmeric
# 102247     Kerala       WAYANAD       2014  Winter               Rice
#
#            Area  Production       Zones    cat_crop
# 97987    2253.0     1518.00  South Zone        Nuts
# ...

# %%
df6['Season'].value_counts()
# Out:
# Whole Year     3045
# Kharif          257
# Winter          245
# Summer          235
# Autumn          221
# Name: Season, dtype: int64

# %%
c=df6.groupby('Season')['Production'].sum()

# %%
df7=pd.DataFrame(c)
df7['Season']=df7.index
df8=df7.sort_values(by='Production').head(4)
df8
# Out:
#              Production       Season
# Season
# Kharif        120672.95  Kharif
# Summer       2093790.53  Summer
# Autumn       3442449.33  Autumn
# Winter       5057205.72  Winter

# %%
plt.figure(figsize=(10,10))
plt.pie(df8['Production'], labels=df8['Season'], autopct='%.0f%%')
plt.title('Season Wise Production In Kerala')
plt.show()

# %% [markdown]
# Production rate is very high during winters in Kerala as a result Kerala must be a major supplier of food items harvested in winter season in Southern India.

# %%
d=df6.groupby('Crop')['Production'].sum()

# %%
df9=pd.DataFrame(d)
df9
# Out:
#                            Production
# Crop
# Arecanut                 1.893642e+06
# Arhar/Tur                5.224000e+03
# Banana                   7.655662e+06
# Bhindi                   1.300000e+01
# Bitter Gourd             0.000000e+00
# Black pepper             9.715301e+05
# Brinjal                  0.000000e+00
# Cardamom                 1.363420e+05
# Cashewnut                9.483952e+05
# Cashewnut Raw            6.608700e+04
# Coconut                  9.780304e+10
# Coffee                   1.300120e+05
# Cotton(lint)             5.998200e+04
# Drum Stick               7.711300e+04
# Dry chillies             5.980000e+02
# Dry ginger               6.010938e+05
# Garlic                   9.225500e+04
# Groundnut                3.117900e+04
# Jack Fruit               6.610000e+02
# Jowar                    1.441100e+04
# Maize                    1.550000e+02
# Mango                    1.650151e+06
# Other Cereals & Millets  1.989000e+03
# ...

# %%
df9=df9.sort_values(by='Production',ascending=False).head(10)
df9['Crop']=df9.index
df9
# Out:
#                 Production          Crop
# Crop
# Coconut       9.780304e+10      Coconut
# Tapioca       4.611366e+07       Tapioca
# Rice          1.059335e+07          Rice
# Banana        7.655662e+06        Banana
# Sugarcane     3.819916e+06     Sugarcane
# Arecanut      1.893642e+06      Arecanut
# Mango         1.650151e+06         Mango
# Rubber        1.175267e+06        Rubber
# Black pepper  9.715301e+05  Black pepper
# Cashewnut     9.483952e+05     Cashewnut

# %%
plt.figure(figsize=(11,11))
sns.barplot(x='Crop',y='Production',data=df9)
plt.yscale('log')
plt.title('Top 10 Crop Production In Kerala')
# Out:
# Text(0.5, 1.0, 'Top 10 Crop Production In Kerala')

# %% [markdown]
# Analysis of individual crop production shows us that among the Nuts category which collectively has less production than other categories, Coconut is the mass produced food item in Kerala.

# %%
e=df2[df2.columns[df2.columns.isin(['State_Name','Production','cat_crop'])]]
df10=pd.DataFrame(e)
df10=df10.dropna(axis=0,how='any')
df10=df10.groupby('State_Name').max('Production')
df10['State_Name']=df10.index
df10
# Out:
#                               Production                   State_Name
# State_Name
# Andaman and Nicobar Islands     31863.00  Andaman and Nicobar Islands
# Andhra Pradesh                4097998.00               Andhra Pradesh
# Arunachal Pradesh               35010.00            Arunachal Pradesh
# Assam                          397881.00                        Assam
# Bihar                         9614539.00                        Bihar
# Chandigarh                       3960.00                   Chandigarh
# Chhattisgarh                  2129180.00                 Chhattisgarh
# Dadra and Nagar Haveli         122960.00       Dadra and Nagar Haveli
# Goa                             85664.00                          Goa
# Gujarat                      11754000.00                      Gujarat
# Haryana                       2894000.00                      Haryana
# Himachal Pradesh               170283.00             Himachal Pradesh
# ...

# %%
Production = df10["Production"].values.tolist()
State= df10["State_Name"].tolist()

# %%
df11=pd.DataFrame(e)
df11
# Out:
#                          State_Name  Production    cat_crop
# 0       Andaman and Nicobar Islands      2000.0        Nuts
# 1       Andaman and Nicobar Islands         1.0      Pulses
# 2       Andaman and Nicobar Islands       321.0      Cereal
# 3       Andaman and Nicobar Islands       641.0      Fruits
# 4       Andaman and Nicobar Islands       165.0        Nuts
# ...                             ...         ...         ...
# 246086                  West Bengal       801.0      Cereal
# 246087                  West Bengal       463.0    oilseeds
# 246088                  West Bengal     16250.0  Commercial
# 246089                  West Bengal    597899.0      Cereal
# 246090                  West Bengal        88.0    oilseeds
#
# [242361 rows x 3 columns]

# %%
df11=df11.loc[df11['Production'].isin(Production)]

# %%
df11
# Out:
#                          State_Name   Production    cat_crop
# 81      Andaman and Nicobar Islands     31863.00      Cereal
# 1066                 Andhra Pradesh   4097998.00  Commercial
# 2209                 Andhra Pradesh    715000.00      Cereal
# 5067                 Andhra Pradesh     53997.00        Nuts
# 7090                 Andhra Pradesh     31863.00        Nuts
# 10054             Arunachal Pradesh     35010.00      Cereal
# 18730                         Assam      3960.00      Fruits
# 23763                         Assam    397881.00  Commercial
# 39340                         Bihar   9614539.00  Commercial
# 45898                    Chandigarh      3960.00      Cereal
# 46358                  Chhattisgarh   2129180.00  Commercial
# 56778        Dadra and Nagar Haveli    122960.00  Commercial
# 56959                           Goa     85664.00      Cereal
# 64203                       Gujarat  11754000.00  Commercial
# ...

# %%
df11=df11.sort_values(by='Production',ascending=False)

# %%
df11
# Out:
#                          State_Name   Production    cat_crop
# 190249                   Tamil Nadu  37158000.00  Commercial
# 136558                  Maharashtra  20049700.00  Commercial
# 79070                     Karnataka  18027470.00  Commercial
# 218796                Uttar Pradesh  17757963.00  Commercial
# 64203                       Gujarat  11754000.00  Commercial
# 39340                         Bihar   9614539.00  Commercial
# 244878                  West Bengal   7556300.00    oilseeds
# 233684                  Uttarakhand   4630801.00  Commercial
# 1066                 Andhra Pradesh   4097998.00  Commercial
# 71340                       Haryana   2894000.00  Commercial
# 194176                   Telangana    2645000.00  Commercial
# 46358                  Chhattisgarh   2129180.00  Commercial
# 203394                Uttar Pradesh   2129180.00  Commercial
# 162160                       Punjab   1969000.00      Cereal
# ...

# %%
df12 = df11.drop_duplicates(subset=["State_Name"])

# %%
df12
# Out:
#                          State_Name   Production    cat_crop
# 190249                   Tamil Nadu  37158000.00  Commercial
# 136558                  Maharashtra  20049700.00  Commercial
# 79070                     Karnataka  18027470.00  Commercial
# 218796                Uttar Pradesh  17757963.00  Commercial
# 64203                       Gujarat  11754000.00  Commercial
# 39340                         Bihar   9614539.00  Commercial
# 244878                  West Bengal   7556300.00    oilseeds
# 233684                  Uttarakhand   4630801.00  Commercial
# 1066                 Andhra Pradesh   4097998.00  Commercial
# 71340                       Haryana   2894000.00  Commercial
# 194176                   Telangana    2645000.00  Commercial
# 46358                  Chhattisgarh   2129180.00  Commercial
# 162160                       Punjab   1969000.00      Cereal
# 115776               Madhya Pradesh   1545480.00  Commercial
# ...

# %%
df12.shape
# Out:
# (33, 3)

# %%
df12['cat_crop'].nunique()
# Out:
# 4

# %%
plt.figure(figsize=(20,9))
sns.barplot(x='State_Name',y='Production',data=df12,hue='cat_crop',dodge=False)
plt.yscale('log')
plt.legend(loc='lower left')
plt.xticks(rotation=90)
plt.title('Top Crop Categories Produced In Each State')
plt.show()

# %% [markdown]
# From the above visualisation we can make the inference that Commercial Crops and Cereals are widely grown crop categories across whole India.

# %% [markdown]
# # Libraries

# %%
from sklearn.model_selection import train_test_split

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pal = sns.husl_palette(h=.5)

# %% [markdown]
# # **Dataset 1: Classification Dataset to Recommend crop category based on Soil Fertility**

# %%
data_1 = pd.read_csv('/content/Soil Fertility - Crop Recommendation.csv')

data_1.head(5)
# Out:
#       N (%)     P (%)     K (%)  temperature (C)  relative humidity (%)  \
# 0  2.614216  0.275071  3.648523        24.445057              55.927795
# 1  3.682413  0.217083  2.338205        21.102826              61.671531
# 2  2.022518  0.492536  3.272810        17.852463              62.431984
# 3  1.140960  0.397023  2.242730        21.237408              75.258847
# 4  2.971729  0.426558  3.104570        21.036508              69.911553
#
#          ph       label
# 0  6.181546      Cereal
# 1  5.818589      Cereal
# 2  6.066725      Cereal
# 3  7.609967      Cereal
# 4  6.465731  Vegetables

# %%
data_1.shape
# Out:
# (699, 7)

# %%
data_1['label'].unique()
# Out:
# array(['Cereal', 'Vegetables', 'Pulses'], dtype=object)

# %%
# Import label encoder
from sklearn import preprocessing

# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()

# Encode labels in column 'species'.
data_1['label']= label_encoder.fit_transform(data_1['label'])

# %%
x = data_1.drop(['label'], axis = 1)
y = data_1['label']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.30, random_state = 0)

# %%
x_train.shape
# Out:
# (489, 6)

# %%
y_train.shape
# Out:
# (489,)

# %%
value_counts = data_1['label'].value_counts()

# Plot the value counts as a bar chart
sns.barplot(x=value_counts.index, y=value_counts.values, palette = pal)
plt.title('Distribution of Target Variable')
plt.xlabel('Target Variable')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Thus, from the above graph we come to know that there in no data imbalance in this dataset

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.svm import SVC, SVR
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor, AdaBoostClassifier, AdaBoostRegressor
from sklearn.linear_model import LogisticRegression, LinearRegression
from xgboost import XGBClassifier, XGBRegressor
from lightgbm import LGBMClassifier, LGBMRegressor
from sklearn import linear_model
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, PolynomialFeatures

# %% [markdown]
# # Classification Models

# %% [markdown]
# ### Naive Bayes Classifier

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()

'''param_grid = {
    'alpha': [0.1, 0.5, 1.0, 2.0, 0.001, 0.01],
}'''

'''# define the grid search object
grid_search = GridSearchCV(nb, param_grid, cv=5)

# fit the grid search object to the data
grid_search.fit(x_train, y_train)

# get the best hyperparameters
best_params = grid_search.best_params_'''

# retrain the model with the best hyperparameters
nb_best = GaussianNB()
nb_best.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
data = {'Data': ['Training', 'Testing'],
        'Accuracy': [nb_best.score(x_train,y_train), nb_best.score(x_test,y_test)]}

# Create DataFrame
df = pd.DataFrame(data)

# %%
plt.figure(figsize=(10,6))
sns.set(font_scale=1.2)

sns.barplot(x='Accuracy', y='Data', data=df, ci='sd', palette = pal)

plt.xlabel("Accuracy")
plt.ylabel("Data")
plt.title("Training - Testing Accuracy")
plt.show()
# Out:
# <ipython-input-237-e80d6e120d78>:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(x='Accuracy', y='Data', data=df, ci='sd', palette = pal)

# %% [markdown]
# ### DT Classifier

# %%
cm_dtc = Pipeline([('std_scaler', StandardScaler()), ('dtc_classifier', DecisionTreeClassifier())])

# Define the hyperparameters to tune
param_grid = {'dtc_classifier__max_depth': [3, 6, 9, 12]}

# Perform GridSearchCV for hyperparameter tuning
grid_search = GridSearchCV(cm_dtc, param_grid, cv=5)
grid_search.fit(x_train, y_train)

# Get the best hyperparameters
best_params = grid_search.best_params_
print("Best Parameters:", best_params)
# Out:
# Best Parameters: {'dtc_classifier__max_depth': 12}

# %%
cm_dtc.set_params(**best_params)
cm_dtc.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('std_scaler', StandardScaler()),
#                 ('dtc_classifier', DecisionTreeClassifier(max_depth=12))])

# %%
data = {'Data': ['Training', 'Testing'],
        'Accuracy': [cm_dtc.score(x_train,y_train), cm_dtc.score(x_test,y_test)]}

# Create DataFrame
df = pd.DataFrame(data)

# %%
plt.figure(figsize=(10,6))
sns.set(font_scale=1.2)

sns.barplot(x='Accuracy', y='Data', data=df, ci='sd', palette = pal)

plt.xlabel("Accuracy")
plt.ylabel("Data")
plt.title("Training - Testing Accuracy")
plt.show()
# Out:
# <ipython-input-241-e80d6e120d78>:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(x='Accuracy', y='Data', data=df, ci='sd', palette = pal)

# %% [markdown]
# ### Adaboost Classifier

# %%
cm_ada = Pipeline([
    ('std_scaler', StandardScaler()),
    ('ada_classifier', AdaBoostClassifier())
])

# Define the hyperparameters to tune
param_grid = {
    'ada_classifier__n_estimators': [50, 100, 200],
    'ada_classifier__learning_rate': [0.1, 0.5, 1.0],
    'ada_classifier__base_estimator': [DecisionTreeClassifier(max_depth=2)],
    'ada_classifier__algorithm': ['SAMME'],
}


# Perform GridSearchCV for hyperparameter tuning
grid_search = GridSearchCV(cm_ada, param_grid, cv=5)
grid_search.fit(x_train, y_train)

# Get the best hyperparameters
best_params = grid_search.best_params_
print("Best Parameters:", best_params)

# %%
cm_ada.set_params(**best_params)
cm_ada.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# Pipeline(steps=[('std_scaler', StandardScaler()),
#                 ('ada_classifier',
#                  AdaBoostClassifier(algorithm='SAMME',
#                                     base_estimator=DecisionTreeClassifier(max_depth=2),
#                                     learning_rate=0.1, n_estimators=200))])

# %%
data = {'Data': ['Training', 'Testing'],
        'Accuracy': [cm_ada.score(x_train,y_train), cm_ada.score(x_test,y_test)]}

# Create DataFrame
df = pd.DataFrame(data)

# %%
plt.figure(figsize=(10,6))
sns.set(font_scale=1.2)

sns.barplot(x='Accuracy', y='Data', data=df, ci='sd', palette = pal)

plt.xlabel("Accuracy")
plt.ylabel("Data")
plt.title("Training - Testing Accuracy")
plt.show()
# Out:
# <ipython-input-245-e80d6e120d78>:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(x='Accuracy', y='Data', data=df, ci='sd', palette = pal)

# %% [markdown]
# ### LightGBM Classifier Model

# %%
cm_lgbm = Pipeline([('lightGBM_classifier', LGBMClassifier())])

# Define the hyperparameters to tune
param_grid = {'lightGBM_classifier__learning_rate': [0.1, 0.01 ,0.2],
              'lightGBM_classifier__n_estimators': [100, 200, 300],
              'lightGBM_classifier__max_depth': [3, 5, 7]}

# Perform GridSearchCV for hyperparameter tuning
grid_search = GridSearchCV(cm_lgbm, param_grid, cv=5)
grid_search.fit(x_train, y_train)

# Get the best hyperparameters
best_params = grid_search.best_params_
print("Best Parameters:", best_params)
# Out:
# Best Parameters: {'lightGBM_classifier__learning_rate': 0.2, 'lightGBM_classifier__max_depth': 3, 'lightGBM_classifier__n_estimators': 100}

# %%
cm_lgbm.set_params(**best_params)
cm_lgbm.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('lightGBM_classifier',
#                  LGBMClassifier(learning_rate=0.2, max_depth=3))])

# %%
data = {'Data': ['Training', 'Testing'],
        'Accuracy': [cm_lgbm.score(x_train,y_train), cm_lgbm.score(x_test,y_test)]}

# Create DataFrame
df = pd.DataFrame(data)

# %%
plt.figure(figsize=(10,6))
sns.set(font_scale=1.2)

sns.barplot(x='Accuracy', y='Data', data=df, ci='sd', palette = pal)

plt.xlabel("Accuracy")
plt.ylabel("Data")
plt.title("Gradient-Boost")
plt.show()
# Out:
# <ipython-input-249-2aff0aba75b3>:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(x='Accuracy', y='Data', data=df, ci='sd', palette = pal)

# %% [markdown]
# ### XGBoost Classifier

# %%
param_grid = {
    'max_depth': [5],
    'min_child_weight': [1],
    'gamma': [0.5],
    'reg_lambda': [1],
    'reg_alpha': [1],
    'learning_rate': [0.1]
}

# Create the XGBoost classifier
cm_xgb = XGBClassifier(random_state=5)

# Perform grid search with cross-validation
grid_search = GridSearchCV(cm_xgb, param_grid, cv=5)
grid_search.fit(x_train, y_train)

# Get the best hyperparameters
best_params = grid_search.best_params_
print("Best Parameters:", best_params)
# Out:
# Best Parameters: {'gamma': 0.5, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 1, 'reg_alpha': 1, 'reg_lambda': 1}

# %%
cm_xgb.set_params(**best_params)
cm_xgb.fit(x_train, y_train)

# %%
data = {'Data': ['Training', 'Testing'],
        'Accuracy': [cm_xgb.score(x_train,y_train), cm_xgb.score(x_test,y_test)]}

# Create DataFrame
df = pd.DataFrame(data)

# %%
plt.figure(figsize=(10,6))
sns.set(font_scale=1.2)

sns.barplot(x='Accuracy', y='Data', data=df, ci='sd', palette = pal)

plt.xlabel("Accuracy")
plt.ylabel("Data")
plt.title("Training - Testing Accuracy")
plt.show()
# Out:
# <ipython-input-253-e80d6e120d78>:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(x='Accuracy', y='Data', data=df, ci='sd', palette = pal)

# %% [markdown]
# ### Logistic Regression

# %%
cm_logr = Pipeline([('logr_classifier', LogisticRegression(random_state=0))])
param_grid = {
    'logr_classifier__C': [0.1, 1, 10],
    'logr_classifier__solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']
}

# Perform GridSearchCV for hyperparameter tuning
grid_search = GridSearchCV(cm_logr, param_grid, cv=5)
grid_search.fit(x_train, y_train)

# Get the best hyperparameters
best_params = grid_search.best_params_
print("Best Parameters:", best_params)

# %%
cm_logr.set_params(**best_params)
cm_logr.fit(x_train, y_train)

# %%
data = {'Data': ['Training', 'Testing'],
        'Accuracy': [cm_xgb.score(x_train,y_train), cm_xgb.score(x_test,y_test)]}

# Create DataFrame
df = pd.DataFrame(data)

# %%
plt.figure(figsize=(10,6))
sns.set(font_scale=1.2)

sns.barplot(x='Accuracy', y='Data', data=df, ci='sd', palette = pal)

plt.xlabel("Accuracy")
plt.ylabel("Data")
plt.title("Training - Testing Accuracy")
plt.show()
# Out:
# <ipython-input-257-e80d6e120d78>:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(x='Accuracy', y='Data', data=df, ci='sd', palette = pal)

# %% [markdown]
# ### SVM Classifier

# %%
cm_svm = Pipeline([('std_scaler', StandardScaler()),('svm_classifier',SVC(kernel='poly',C=1500))])

# %%
cm_svm.fit(x_train, y_train)

# %%
data = {'Data': ['Training', 'Testing'],
        'Accuracy': [cm_svm.score(x_train,y_train), cm_svm.score(x_test,y_test)]}

# Create DataFrame
df = pd.DataFrame(data)

# %%
plt.figure(figsize=(10,6))
sns.set(font_scale=1.2)

sns.barplot(x='Accuracy', y='Data', data=df, ci='sd', palette = pal)

plt.xlabel("Accuracy")
plt.ylabel("Data")
plt.title("Training - Testing Accuracy")
plt.show()
# Out:
# <ipython-input-261-e80d6e120d78>:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(x='Accuracy', y='Data', data=df, ci='sd', palette = pal)

# %% [markdown]
# # Final Classification Analysis

# %%
models = ['Naive Bayes','Decision Tree','SVM','AdaBoost','XGBoost','Logestic Regression','LightGBM']
result = pd.DataFrame(models,columns=['Models'])

# %%
m = [nb_best,cm_dtc,cm_svm,cm_ada,cm_xgb,cm_logr,cm_lgbm]
train = []
test = []
for i in m:
    train.append(i.score(x_train,y_train))
    test.append(i.score(x_test,y_test))

# %%
result['Train_score'] = train
result['Test_score'] = test

# %%
result
# Out:
#                 Models  Train_score  Test_score
# 0          Naive Bayes     0.928425    0.919048
# 1        Decision Tree     0.997955    0.904762
# 2                  SVM     0.963190    0.842857
# 3             AdaBoost     0.993865    0.904762
# 4              XGBoost     0.985685    0.909524
# 5  Logestic Regression     0.883436    0.885714
# 6             LightGBM     1.000000    0.890476

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create the dataset
models = ['Naive Bayes','Decision Tree', 'SVM', 'AdaBoost', 'XGBoost', 'Logestic Regression', 'LightGBM']
train_scores = [0.93, 0.92, 0.96, 0.99, 0.99, 0.88, 1.00]
test_scores = [0.92, 0.88, 0.84, 0.90, 0.91, 0.89, 0.89]

# Create a bar plot using Seaborn
sns.set_style('whitegrid')
plt.figure(figsize=(14, 14))

# Melt the data into a long format
df_melt = pd.melt(result, id_vars='Models', var_name='Scores', value_name='Value')

ax = sns.barplot(x='Models', y='Value', hue='Scores', data=df_melt, palette = pal)

# Add annotations to the plot
for i, score in enumerate(test_scores):
    ax.text(i, score+0.01, str(score), ha='left', fontsize=10)

for i, score in enumerate(train_scores):
    ax.text(i, score+0.01, str(score), ha='right', fontsize=10)

# Add labels and title
plt.xlabel('MODELS')
plt.ylabel('ACCURACY')
plt.title('Comparison of Accuracy Scores for Different Models')

m = [nb_best,cm_dtc,cm_svm,cm_ada,cm_xgb,cm_logr,cm_lgbm]
k = -0.15
l = 0
for i in m:
  for j in range(1):
    plt.text(0.60, k, f" Difference in Both Accuracy for {models[l]} : {abs(i.score(x_train,y_train) - i.score(x_test,y_test))}" , horizontalalignment='center',verticalalignment='center',fontsize=12)
    k = k-0.05
    l = l + 1

# Show the plot
plt.show()

# %% [markdown]
# Therefore, from the above graph we can understand that Naive Bayes Classification Model is best suited for this dataset because this model has high accuracy & is not overfitting (negligible difference between training & testing dataset)

# %% [markdown]
# # **Dataset 2: Regression Dataset to Predict generalised crop production based on recommended Crop Category**

# %%
data_2 = DF1
data_2.head()
# Out:
#     State_Name  District_Name  Crop_Year  Season  Crop   Area  Production  \
# 1            0            427       2000       1    28    2.0         1.0
# 2            0            427       2000       1    38  102.0       321.0
# 8            0            427       2000       4    43    5.0        15.0
# 9            0            427       2000       4    44   40.0       169.0
# 11           0            427       2001       1    28    2.0         1.0
#
#     Zones  cat_crop
# 1       5         1
# 2       5         0
# 8       5         2
# 9       5         2
# 11      5         1

# %%
# Import label encoder
from sklearn import preprocessing

# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()

# Encode labels in column 'species'.
data_2['State_Name']= label_encoder.fit_transform(data_2['State_Name'])
data_2['District_Name']= label_encoder.fit_transform(data_2['District_Name'])
data_2['Season']= label_encoder.fit_transform(data_2['Season'])
data_2['Crop']= label_encoder.fit_transform(data_2['Crop'])
data_2['Zones']= label_encoder.fit_transform(data_2['Zones'])
data_2['cat_crop']= label_encoder.fit_transform(data_2['cat_crop'])

# %%
X = data_2.drop(['Production'], axis = 1)
y = data_2['Production']

X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size = 0.30, random_state = 0)

# %%
train = []
test = []

# %% [markdown]
# ### Linear Regression

# %%
rm_linr = Pipeline([
    ('std_scaler', StandardScaler()),
    ('linear_regressor', LinearRegression(fit_intercept=False))
])

rm_linr.fit(X_train, Y_train)

Y_pred = rm_linr.predict(X_test)

# %%
train.append(rm_linr.score(X_train,Y_train)), test.append(rm_linr.score(X_test,Y_test))

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, explained_variance_score

# Assuming y_true and y_pred are the true and predicted target values, respectively
# Calculate Mean Squared Error (MSE)
mse_linr = mean_squared_error(Y_test, Y_pred)

# Calculate Root Mean Squared Error (RMSE)
rmse_linr = mean_squared_error(Y_test, Y_pred, squared=False)

# Calculate Mean Absolute Error (MAE)
mae_linr = mean_absolute_error(Y_test, Y_pred)

# Calculate R-squared
r_squared_linr = r2_score(Y_test, Y_pred)

print("Mean Squared Error (MSE): ", mse_linr)
print("Root Mean Squared Error (RMSE): ", rmse_linr)
print("Mean Absolute Error (MAE): ", mae_linr)
print("R-squared: ", r_squared_linr)
# Out:
# Mean Squared Error (MSE):  7636941156.734056
# Root Mean Squared Error (RMSE):  87389.59409869151
# Mean Absolute Error (MAE):  41064.388625170686
# R-squared:  0.44606826771167063

# %% [markdown]
# ### Decision Tree Regressor

# %%
dt = DecisionTreeRegressor()

param_grid = {"max_depth": [3,6,9],
              "max_features": [5, 7,11, 15],
              "min_samples_split": [2, 3, 10],
             "random_state":[2,4,6]}

rm_dtr = Pipeline([('dtr_regressor',GridSearchCV(dt, param_grid=param_grid, cv=5))])

rm_dtr.fit(X_train, Y_train)

Y_pred = rm_dtr.predict(X_test)

# %%
train.append(rm_dtr.score(X_train,Y_train)), test.append(rm_dtr.score(X_test,Y_test))

# %%
# Assuming y_true and y_pred are the true and predicted target values, respectively
# Calculate Mean Squared Error (MSE)
mse_dtr = mean_squared_error(Y_test, Y_pred)

# Calculate Root Mean Squared Error (RMSE)
rmse_dtr = mean_squared_error(Y_test, Y_pred, squared=False)

# Calculate Mean Absolute Error (MAE)
mae_dtr = mean_absolute_error(Y_test, Y_pred)

# Calculate R-squared
r_squared_dtr = r2_score(Y_test, Y_pred)

print("Mean Squared Error (MSE): ", mse_dtr)
print("Root Mean Squared Error (RMSE): ", rmse_dtr)
print("Mean Absolute Error (MAE): ", mae_dtr)
print("R-squared: ", r_squared_dtr)
# Out:
# Mean Squared Error (MSE):  1235556476.2922587
# Root Mean Squared Error (RMSE):  35150.48330097694
# Mean Absolute Error (MAE):  9812.115590571811
# R-squared:  0.910381142763011

# %% [markdown]
# ###Random Forest Regressor

# %%
rm_rfr = RandomForestRegressor(n_estimators=150,max_depth=7,random_state=5)

rm_rfr.fit(X_train, Y_train)

# %%
train.append(rm_rfr.score(X_train,Y_train)), test.append(rm_rfr.score(X_test,Y_test))

# %%
Y_pred = rm_rfr.predict(X_test)

# %%
# Assuming y_true and y_pred are the true and predicted target values, respectively
# Calculate Mean Squared Error (MSE)
mse_rfr = mean_squared_error(Y_test, Y_pred)

# Calculate Root Mean Squared Error (RMSE)
rmse_rfr = mean_squared_error(Y_test, Y_pred, squared=False)

# Calculate Mean Absolute Error (MAE)
mae_rfr = mean_absolute_error(Y_test, Y_pred)

# Calculate R-squared
r_squared_rfr = r2_score(Y_test, Y_pred)

print("Mean Squared Error (MSE): ", mse_rfr)
print("Root Mean Squared Error (RMSE): ", rmse_rfr)
print("Mean Absolute Error (MAE): ", mae_rfr)
print("R-squared: ", r_squared_rfr)
# Out:
# Mean Squared Error (MSE):  1232571427.0452752
# Root Mean Squared Error (RMSE):  35107.99662534556
# Mean Absolute Error (MAE):  10622.31216117541
# R-squared:  0.9105976579182823

# %% [markdown]
# ###Adaboost Regression Model

# %%
rm_ada = Pipeline([('std_scaler', StandardScaler()),('adaboost_regressor',
              AdaBoostRegressor(random_state=5, n_estimators=100,loss='square',learning_rate=1))])

# %%
rm_ada.fit(X_train, Y_train)

# %%
train.append(rm_ada.score(X_train,Y_train)), test.append(rm_ada.score(X_test,Y_test))

# %%
Y_pred = rm_ada.predict(X_test)

# %%
# Assuming y_true and y_pred are the true and predicted target values, respectively
# Calculate Mean Squared Error (MSE)
mse_ada = mean_squared_error(Y_test, Y_pred)

# Calculate Root Mean Squared Error (RMSE)
rmse_ada = mean_squared_error(Y_test, Y_pred, squared=False)

# Calculate Mean Absolute Error (MAE)
mae_ada = mean_absolute_error(Y_test, Y_pred)

# Calculate R-squared
r_squared_ada = r2_score(Y_test, Y_pred)

print("Mean Squared Error (MSE): ", mse_ada)
print("Root Mean Squared Error (RMSE): ", rmse_ada)
print("Mean Absolute Error (MAE): ", mae_ada)
print("R-squared: ", r_squared_ada)
# Out:
# Mean Squared Error (MSE):  8811961368.89792
# Root Mean Squared Error (RMSE):  93872.04785716523
# Mean Absolute Error (MAE):  72198.967543608
# R-squared:  0.36084029904730563

# %% [markdown]
# ###LightGBM Regressor

# %%
from sklearn.model_selection import RandomizedSearchCV

# Create the pipeline
rm_lgbm = Pipeline([
    ('std_scaler', StandardScaler()),
    ('lightgbm_regressor', LGBMRegressor())
])

# Define the hyperparameters to tune
param_grid = {
    'lightgbm_regressor__learning_rate': [0.01, 0.1, 0.2, 0.3],
    'lightgbm_regressor__n_estimators': [50, 100, 200],
    'lightgbm_regressor__max_depth': [3, 5, 7],
    'lightgbm_regressor__reg_alpha': [0, 0.1, 0.5, 1.0],
    'lightgbm_regressor__reg_lambda': [0, 0.1, 0.5, 1.0]
}

# Perform RandomizedSearchCV for hyperparameter tuning
random_search = RandomizedSearchCV(
    rm_lgbm,
    param_distributions=param_grid,
    n_iter=10,  # Specify the number of random combinations to sample
    cv=5,
    scoring='neg_mean_squared_error',
    random_state=42
)

random_search.fit(X_train, Y_train)

best_params = random_search.best_params_
print("Best Parameters:", best_params)
# Out:
# Best Parameters: {'lightgbm_regressor__reg_lambda': 0, 'lightgbm_regressor__reg_alpha': 1.0, 'lightgbm_regressor__n_estimators': 200, 'lightgbm_regressor__max_depth': 5, 'lightgbm_regressor__learning_rate': 0.2}

# %%
rm_lgbm.set_params(**best_params)
rm_lgbm.fit(X_train, Y_train)

# %%
train.append(rm_lgbm.score(X_train,Y_train)), test.append(rm_lgbm.score(X_test,Y_test))

# %%
Y_pred = rm_lgbm.predict(X_test)

# %%
# Assuming y_true and y_pred are the true and predicted target values, respectively
# Calculate Mean Squared Error (MSE)
mse_lgbm = mean_squared_error(Y_test, Y_pred)

# Calculate Root Mean Squared Error (RMSE)
rmse_lgbm = mean_squared_error(Y_test, Y_pred, squared=False)

# Calculate Mean Absolute Error (MAE)
mae_lgbm = mean_absolute_error(Y_test, Y_pred)

# Calculate R-squared
r_squared_lgbm = r2_score(Y_test, Y_pred)

print("Mean Squared Error (MSE): ", mse_lgbm)
print("Root Mean Squared Error (RMSE): ", rmse_lgbm)
print("Mean Absolute Error (MAE): ", mae_lgbm)
print("R-squared: ", r_squared_lgbm)
# Out:
# Mean Squared Error (MSE):  624286461.8509537
# Root Mean Squared Error (RMSE):  24985.725161598846
# Mean Absolute Error (MAE):  7716.44429337674
# R-squared:  0.9547185091308026

# %% [markdown]
# ###XGBoost Regressor

# %%
rm_xgb = Pipeline([('std_scaler', StandardScaler()),('xgboost_regressor',XGBRegressor(n_estimators=50,max_depth=3))])
param_grid = {
    'xgboost_regressor__learning_rate': [0.01, 0.1, 0.2, 0.3],
    'xgboost_regressor__subsample': [0.6, 0.7, 0.8, 0.9, 1.0],
    'xgboost_regressor__colsample_bytree': [0.6, 0.7, 0.8, 0.9, 1.0],
    'xgboost_regressor__reg_alpha': [0, 0.1, 0.5, 1.0],
    'xgboost_regressor__reg_lambda': [0, 0.1, 0.5, 1.0]
}
random_search = RandomizedSearchCV(
    rm_xgb,
    param_distributions=param_grid,
    n_iter=10,  # Specify the number of random combinations to sample
    cv=10,
    scoring='neg_mean_squared_error',
    random_state=42
)

random_search.fit(X_train, Y_train)

best_params = random_search.best_params_
print("Best Parameters:", best_params)
# Out:
# Best Parameters: {'xgboost_regressor__subsample': 0.9, 'xgboost_regressor__reg_lambda': 1.0, 'xgboost_regressor__reg_alpha': 0.1, 'xgboost_regressor__learning_rate': 0.3, 'xgboost_regressor__colsample_bytree': 0.9}

# %%
rm_xgb.set_params(**best_params)
rm_xgb.fit(X_train, Y_train)

# %%
train.append(rm_xgb.score(X_train,Y_train)), test.append(rm_xgb.score(X_test,Y_test))

# %%
Y_pred = rm_xgb.predict(X_test)

# %%
# Assuming y_true and y_pred are the true and predicted target values, respectively
# Calculate Mean Squared Error (MSE)
mse_xgb = mean_squared_error(Y_test, Y_pred)

# Calculate Root Mean Squared Error (RMSE)
rmse_xgb = mean_squared_error(Y_test, Y_pred, squared=False)

# Calculate Mean Absolute Error (MAE)
mae_xgb = mean_absolute_error(Y_test, Y_pred)

# Calculate R-squared
r_squared_xgb = r2_score(Y_test, Y_pred)

print("Mean Squared Error (MSE): ", mse_xgb)
print("Root Mean Squared Error (RMSE): ", rmse_xgb)
print("Mean Absolute Error (MAE): ", mae_xgb)
print("R-squared: ", r_squared_xgb)
# Out:
# Mean Squared Error (MSE):  1384121138.341493
# Root Mean Squared Error (RMSE):  37203.7785492481
# Mean Absolute Error (MAE):  13519.774591025407
# R-squared:  0.8996052733518402

# %% [markdown]
# ###SVM Regressor

# %%
rm_svm = Pipeline([('std_scaler', StandardScaler()),('svm_regressor',SVR(kernel='linear'))])

rm_svm.fit(X_train, Y_train)

# %%
train.append(rm_svm.score(X_train,Y_train)), test.append(rm_svm.score(X_test,Y_test))
# Out:
# (None, None)

# %%
Y_pred = rm_svm.predict(X_test)

# %%
# Assuming y_true and y_pred are the true and predicted target values, respectively
# Calculate Mean Squared Error (MSE)
mse_svm = mean_squared_error(Y_test, Y_pred)

# Calculate Root Mean Squared Error (RMSE)
rmse_svm = mean_squared_error(Y_test, Y_pred, squared=False)

# Calculate Mean Absolute Error (MAE)
mae_svm = mean_absolute_error(Y_test, Y_pred)

# Calculate R-squared
r_squared_svm = r2_score(Y_test, Y_pred)

print("Mean Squared Error (MSE): ", mse_svm)
print("Root Mean Squared Error (RMSE): ", rmse_svm)
print("Mean Absolute Error (MAE): ", mae_svm)
print("R-squared: ", r_squared_svm)
# Out:
# Mean Squared Error (MSE):  11167008977.316591
# Root Mean Squared Error (RMSE):  105674.06955973916
# Mean Absolute Error (MAE):  27537.574100280464
# R-squared:  0.19002117466495583

# %% [markdown]
# #Final Prediction Analysis

# %%
models = ['Linear Regression','Decision Tree','Random Forest','AdaBoost','LightGBM','XGBoost','SVM']
Result = pd.DataFrame(models,columns=['Models'])

# %%
m = [rm_linr,rm_dtr,rm_rfr,rm_ada,rm_lgbm,rm_xgb,rm_svm]

MSE = [mse_linr,mse_dtr,mse_rfr,mse_ada,mse_lgbm,mse_xgb,mse_svm]
RMSE = [rmse_linr,rmse_dtr,rmse_rfr,rmse_ada,rmse_lgbm,rmse_xgb,rmse_svm]
MAE = [mae_linr,mae_dtr,mae_rfr,mae_ada,mae_lgbm,mae_xgb,mae_svm]
R2_score = [r_squared_linr,r_squared_dtr,r_squared_rfr,r_squared_ada,r_squared_lgbm,r_squared_xgb,r_squared_svm]

'''for i in m:
    train.append(i.score(X_train,Y_train))
    test.append(i.score(X_test,Y_test))'''
# Out:
# 'for i in m:\n    train.append(i.score(X_train,Y_train))\n    test.append(i.score(X_test,Y_test))'

# %%
Result['Train_score'] = train
Result['Test_score'] = test
#result['MSE'] = MSE
Result['RMSE'] = RMSE
Result['MAE'] = MAE
#result['R2_score'] = R2_score

# %%
Result
# Out:
#               Models  Train_score  Test_score           RMSE           MAE
# 0  Linear Regression     0.432549    0.446068   87389.594099  41064.388625
# 1      Decision Tree     0.945538    0.910381   35150.483301   9812.115591
# 2      Random Forest     0.922124    0.910598   35107.996625  10622.312161
# 3           AdaBoost     0.360243    0.360840   93872.047857  72198.967544
# 4           LightGBM     0.965021    0.954719   24985.725162   7716.444293
# 5            XGBoost     0.897055    0.899605   37203.778549  13519.774591
# 6                SVM     0.196420    0.190021  105674.069560  27537.574100

# %%
# Assuming df is the DataFrame containing the scores as shown in the question
df_sorted = Result.sort_values(by='Test_score', ascending=False)

df_sorted
# Out:
#               Models  Train_score  Test_score           RMSE           MAE
# 4           LightGBM     0.965021    0.954719   24985.725162   7716.444293
# 2      Random Forest     0.922124    0.910598   35107.996625  10622.312161
# 1      Decision Tree     0.945538    0.910381   35150.483301   9812.115591
# 5            XGBoost     0.897055    0.899605   37203.778549  13519.774591
# 0  Linear Regression     0.432549    0.446068   87389.594099  41064.388625
# 3           AdaBoost     0.360243    0.360840   93872.047857  72198.967544
# 6                SVM     0.196420    0.190021  105674.069560  27537.574100

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the data
models = ['Linear Regression','Decision Tree','Random Forest','AdaBoost','LightGBM','XGBoost','SVM']
test_scores = test

# Sort the models and test scores in descending order
sorted_indices = np.argsort(test_scores)[::-1]
models = [models[i] for i in sorted_indices]
test_scores = [test_scores[i] for i in sorted_indices]

# Define the colors
colors = np.linspace(0, 1, len(models))  # Generate a range of colors from 0 (red) to 1 (blue)

# Plot the test scores
plt.figure(figsize=(10, 10))
sns.barplot(x = models, y = test_scores, palette = pal)
plt.xlabel('Models')
plt.ylabel('Test Score')
plt.title('Comparison of Test Scores for Different Models')
plt.xticks(rotation=45)

# Find the index of the best model
best_model_index = test_scores.index(max(test_scores))
best_model = models[best_model_index]

# Annotate the best model
plt.annotate(f'Best Model: {best_model}', (best_model_index, max(test_scores)), xytext=(0, 10),
             textcoords='offset points', ha='center', fontsize=15, fontweight='bold')

# Show the plot
plt.show()

# %%
# Define the data
models = ['Linear Regression','Decision Tree','Random Forest','AdaBoost','LightGBM','XGBoost','SVM']
rms_errors = RMSE

# Sort the models and RMS errors in ascending order
sorted_indices = np.argsort(rms_errors)
models = [models[i] for i in sorted_indices]
rms_errors = [rms_errors[i] for i in sorted_indices]

# Define the colors
colors = np.linspace(0, 1, len(models))  # Generate a range of colors from 0 (red) to 1 (blue)

# Plot the RMS errors
plt.figure(figsize=(10, 10))
sns.barplot(x=models, y=rms_errors, palette=pal)
plt.xlabel('Models')
plt.ylabel('RMS Error')
plt.title('Comparison of RMS Errors for Different Models')
plt.xticks(rotation=45)

# Find the index of the best model
best_model_index = rms_errors.index(min(rms_errors))
best_model = models[best_model_index]

# Annotate the best model
plt.annotate(f'Best Model: {best_model}', (best_model_index, min(rms_errors)), xytext=(0, 10),
             textcoords='offset points', ha='center', fontsize=11, fontweight='bold')

# Show the plot
plt.show()

# %% [markdown]
# Therefore, from the above graph we can understand that Gradient-Boost Regression Model is best suited for this dataset because this model has high accuracy & low RMS error.

# %% [markdown]
# #Final ML Model

# %% [markdown]
# ##Classification

# %%
f_data_clf = pd.read_csv('/content/Soil Fertility - Crop Recommendation.csv')

f_data_clf.head(5)
# Out:
#       N (%)     P (%)     K (%)  temperature (C)  relative humidity (%)  \
# 0  2.614216  0.275071  3.648523        24.445057              55.927795
# 1  3.682413  0.217083  2.338205        21.102826              61.671531
# 2  2.022518  0.492536  3.272810        17.852463              62.431984
# 3  1.140960  0.397023  2.242730        21.237408              75.258847
# 4  2.971729  0.426558  3.104570        21.036508              69.911553
#
#          ph       label
# 0  6.181546      Cereal
# 1  5.818589      Cereal
# 2  6.066725      Cereal
# 3  7.609967      Cereal
# 4  6.465731  Vegetables

# %%
f_data_clf['label']= label_encoder.fit_transform(f_data_clf['label'])

# %%
x = f_data_clf.drop(['label'], axis = 1)
y = f_data_clf['label']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.45, random_state = 42)

# %%
from sklearn.naive_bayes import GaussianNB


nb_best = GaussianNB()
nb_best.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
Y_pred = nb_best.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay, classification_report

# %%
print(f"testing accuracy = {accuracy_score(y_test,Y_pred)}")
# Out:
# testing accuracy = 0.9396825396825397

# %%
cm=confusion_matrix(y_test,Y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()

# %%
print(classification_report(y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92       117
#            1       1.00      1.00      1.00        92
#            2       0.92      0.90      0.91       106
#
#     accuracy                           0.94       315
#    macro avg       0.94      0.94      0.94       315
# weighted avg       0.94      0.94      0.94       315

# %%
test_df = {'N (%)':1.140960,
           'P (%)':0.397023,
           'K (%)':2.242730,
           'temperature (C)':21.237408,
           'relative humidity (%)':75.258847,
           'ph':7.609967}

test_df = pd.DataFrame(test_df, index=[0])
test_df
# Out:
#      N (%)     P (%)    K (%)  temperature (C)  relative humidity (%)  \
# 0  1.14096  0.397023  2.24273        21.237408              75.258847
#
#          ph
# 0  7.609967

# %%
y_pred = nb_best.predict(test_df)
y_pred[0]
# Out:
# 0

# %% [markdown]
# ##Regression

# %%
f_data_reg = DF1
f_data_reg.head()
# Out:
#                      State_Name District_Name  Crop_Year       Season  \
# 1   Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2   Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 8   Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 9   Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 11  Andaman and Nicobar Islands      NICOBARS       2001  Kharif
#
#                    Crop   Area  Production       Zones    cat_crop
# 1   Other Kharif pulses    2.0         1.0  Union Terr      Pulses
# 2                  Rice  102.0       321.0  Union Terr      Cereal
# 8          Sweet potato    5.0        15.0  Union Terr  Vegetables
# 9               Tapioca   40.0       169.0  Union Terr  Vegetables
# 11  Other Kharif pulses    2.0         1.0  Union Terr      Pulses

# %%
f_data_reg['State_Name']= label_encoder.fit_transform(f_data_reg['State_Name'])
f_data_reg['District_Name']= label_encoder.fit_transform(f_data_reg['District_Name'])
f_data_reg['Season']= label_encoder.fit_transform(f_data_reg['Season'])
f_data_reg['Crop']= label_encoder.fit_transform(f_data_reg['Crop'])
f_data_reg['Zones']= label_encoder.fit_transform(f_data_reg['Zones'])
f_data_reg['cat_crop']= label_encoder.fit_transform(f_data_reg['cat_crop'])

# %%
X = f_data_reg.drop(['Production'], axis = 1)
y = f_data_reg['Production']

X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size = 0.30, random_state = 0)

# %%
rm_xgb = Pipeline([('std_scaler', StandardScaler()),
                   ('xgboost_regressor',XGBRegressor(n_estimators=50,max_depth=3,subsample=0.9,
                      reg_lambda=1.0,reg_alpha=0.1,learning_rate=0.3,colsample_bytree=0.9))])

random_search = RandomizedSearchCV(
    rm_xgb,
    param_distributions=param_grid,
    n_iter=10,  # Specify the number of random combinations to sample
    cv=10,
    scoring='neg_mean_squared_error',
    random_state=42
)

random_search.fit(X_train, Y_train)
Y_pred = rm_lgbm.predict(X_test)

# %%
print(f'Accuracy:{rm_lgbm.score(X_test,Y_test)}')
# Out:
# Accuracy:0.9547185091308026

# %%
test_df = {'State_Name':'West Bengal',
           'District_Name':'PURULIA',
           'Crop_Year':2014,
           'Season':'Rabi',
           'Crop':'Wheat',
           'Area':1622.0,
           'Zones':'East Zone',
           'cat_crop':y_pred}

test_df = pd.DataFrame(test_df, index=[0])
test_df
# Out:
#     State_Name District_Name  Crop_Year Season   Crop    Area      Zones  \
# 0  West Bengal       PURULIA       2014   Rabi  Wheat  1622.0  East Zone
#
#    cat_crop
# 0         0

# %%
test_df['State_Name']= label_encoder.fit_transform(test_df['State_Name'])
test_df['District_Name']= label_encoder.fit_transform(test_df['District_Name'])
test_df['Season']= label_encoder.fit_transform(test_df['Season'])
test_df['Crop']= label_encoder.fit_transform(test_df['Crop'])
test_df['Zones']= label_encoder.fit_transform(test_df['Zones'])
test_df['cat_crop']= label_encoder.fit_transform(test_df['cat_crop'])

# %%
Y_pred = rm_lgbm.predict(test_df)
Y_pred[0]
# Out:
# 5297.624274486467
